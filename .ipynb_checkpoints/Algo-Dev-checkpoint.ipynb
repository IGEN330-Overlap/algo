# %% [markdown]
# # Main notebook for the algorithm development and enhancement

# %%
# Required packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set()

# allowing all the columns to be visualized
pd.options.display.max_columns = None

# rendering all graphics straight out of the notebook
# %matplotlib inline

# %%
f1 = pd.read_json("data/SpotifyData.json")
f1.head(2)
# Out:
#      artist_name              track_name                track_id  popularity  \
# 0       24kGoldn  Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq          99
# 1  Ariana Grande                   34+35  6Im9k8u9iIzKMrmV7BWtlF          97
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.70   0.722    7    -3.558     0       0.0369         0.221
# 1          0.83   0.585    0    -6.476     1       0.0940         0.237
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# 0               0.0     0.272    0.756   90.989       140526               4
# 1               0.0     0.248    0.485  109.978       173711               4

# %%
df_BL = pd.read_csv("data/brendan-spotify.csv")
df_NL = pd.read_csv("data/nick-spotify.csv")
df_BT = pd.read_csv("data/btam-spotify.csv")
df_DD = pd.read_csv("data/danica-spotify.csv")
df_TLC = pd.read_csv("data/toma-spotify.csv")

frames = [df_BL, df_NL, df_BT, df_DD, df_TLC]
personal_df = pd.concat(frames).reset_index(drop=True) 
personal_df.head(2)
# Out:
#                 Song        Artist              Genre  Year       added  bpm  \
# 0    Sooner Or Later  Aaron Carter          dance pop  2018  2021‑01‑06  112
# 1  This is the Place   Tom Grennan  indie anthem-folk  2020  2021‑01‑05  142
#
#    energy  dance  dB  liveliness  valence  duration  acousticness  \
# 0      73     74  -7           7       44       213            12
# 1      62     65  -5           9       46       186            32
#
#    speechiness  popularity
# 0            4          49
# 1            3          68

# %%
# Cleaning and prepping data

f1 = f1.drop(columns=['track_id', 'key', 'mode', 'time_signature', 'duration_ms','instrumentalness'])
print(f1.head(2))

# Rename certain columns
personal_df = personal_df.rename(columns={"Song": "track_name", 
                            "Artist": "artist_name", 
                            "dance": "danceability", 
                            "dB": "loudness",
                            "bpm": "tempo",
                            "liveliness":"liveness",
                            })

# Rearrange to match order of master set
personal_df = personal_df[['artist_name', 
                           'track_name',
                           'popularity',
                           'danceability',
                           'energy',
                           'speechiness',
                           'acousticness',
                           'liveness',
                           'valence',
                           'tempo',]]
# print("\n\n",personal_df.head(2))
# Out:
#      artist_name              track_name  popularity  danceability  energy  \
# 0       24kGoldn  Mood (feat. iann dior)          99          0.70   0.722
# 1  Ariana Grande                   34+35          97          0.83   0.585
#
#    loudness  speechiness  acousticness  liveness  valence    tempo
# 0    -3.558       0.0369         0.221     0.272    0.756   90.989
# 1    -6.476       0.0940         0.237     0.248    0.485  109.978

# %%
# Concatenate the datasets
df = pd.concat([f1, personal_df])
df = df.drop_duplicates(subset=['track_name','artist_name'], keep='first', inplace=False, ignore_index=False )

# shape of the dataset
print("Data Frame Dimensions:")
print("Lines:\t\t{}".format(df.shape[0]))
print("Columns:\t{}".format(df.shape[1]))

# Verify no missing data
print(df.info())
# Out:
# Data Frame Dimensions:
# Lines:		22663
# Columns:	11
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22663 entries, 0 to 3694
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_name   22663 non-null  object
#  1   track_name    22663 non-null  object
#  2   popularity    22663 non-null  int64
#  3   danceability  22663 non-null  float64
#  4   energy        22663 non-null  float64
#  5   loudness      20745 non-null  float64
#  6   speechiness   22663 non-null  float64
#  7   acousticness  22663 non-null  float64
#  8   liveness      22663 non-null  float64
#  9   valence       22663 non-null  float64
#  10  tempo         22663 non-null  float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 2.1+ MB
# None

# %%
# statistical distribution of categorical values
df.describe(include="O")
# Out:
#        artist_name track_name
# count        22663      22663
# unique        6866      20841
# top          Drake       Home
# freq           153         13

# %%
# checking most recurrent artists
n = 10
print("Most Popular Artists")
df['artist_name'].value_counts()[:n]
# Out:
# Most Popular Artists
# Drake                153
# Roy Orbison          150
# TandMProductionCo    145
# Taylor Swift         128
# BTS                  110
# Robin Trower          96
# The Weeknd            95
# David Bowie           94
# One Direction         92
# Mac Miller            87
# Name: artist_name, dtype: int64

# %%
def createGroupTopPlaylist(frames):
    """
    frames: list of the df containing individual song libraries
    """
    playlistLen = 20;
    
    

    
#     df = df.drop_duplicates(subset=['track_name','artist_name'], keep='first', inplace=False, ignore_index=False )
    
    
    
    # Calculates song difference attribute for each song
    df = df.assign(delta=lambda x: 
                       abs(x['energy'] - moodProfile[0]) * weightParams[0]
                       + abs(x['dance'] - moodProfile[1]) * weightParams[1]
                       + abs(x['valence'] - moodProfile[2]) * weightParams[2]
                       + abs(x['popularity']- moodProfile[3]) * weightParams[3]
                  )

# %%
tmp1 = pd.read_json('data/brendan-top-med-track.json')
tmp2 = pd.read_json('data/btam-top-med-track.json')
tmp3 = pd.read_json('data/kevin-top-med-track.json')
tmp4 = pd.read_json('data/remy-top-med-track.json')

# print(tmp1.head(2), "\n\n", tmp2.head(2), "\n\n", tmp3.head(2))
# Out:
#   trackName                 trackID  popularity                 artistName  \
# 0      2all  0ZfEeIu7CNHQhbCTiVv3cx          54  Catfish and the Bottlemen
# 1   Shelter  2CgOd0Lj5MuvOqzqdaAXtS          65            Porter Robinson
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.396   0.778    7    -3.990     0       0.0718       0.00246
# 1         0.276   0.796    0    -4.499     1       0.0579       0.00293
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0           0.00291    0.0952    0.362  166.846       188440
# 1           0.00000    0.1840    0.260  199.526       218965
#
#                                  trackName                 trackID  popularity  \
# 0  Monster (Shawn Mendes & Justin Bieber)  2Z8yfpFX0ZMavHkcIeHiO1          88
# 1                   This Side of Paradise  3sgf2a905hjZ81tXYytY6i          55
#
#       artistName  danceability  energy  key  loudness  mode  speechiness  \
# 0   Shawn Mendes         0.652   0.383    2    -7.076     0       0.0516
# 1  Coyote Theory         0.278   0.662    9    -6.075     1       0.0295
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms
# 0        0.0676          0.000000    0.0828    0.549  145.765       178994
# 1        0.3860          0.000011    0.1340    0.274  181.683       242013
#
#                    trackName                 trackID  popularity artistName  \
# 0                    lowkey  5TTXEcfsYLh6fTarLaevTi          73       NIKI
# 1  SLOW DANCING IN THE DARK  0rKtyWc8bvkriBthvHKY8d          83       Joji
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.752   0.494    0    -8.180     1       0.0559         0.432
# 1         0.515   0.479    3    -7.458     1       0.0261         0.544
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0           0.00000    0.0869    0.227  117.901       171356
# 1           0.00598    0.1910    0.284   88.964       209274

# %%
group_df = pd.concat([tmp1,tmp2,tmp3,tmp4]).reset_index(drop=True)
group_df
# Out:
#                                              trackName  \
# 0                                                 2all
# 1                                              Shelter
# 2                                          Take a Walk
# 3                                              Escapee
# 4                                             Longshot
# ..                                                 ...
# 195                                         REEL IT IN
# 196                                           Language
# 197                                         North Face
# 198                                        Let Me Know
# 199  F**kin' Problems (feat. Drake, 2 Chainz & Kend...
#
#                     trackID  popularity                 artistName  \
# 0    0ZfEeIu7CNHQhbCTiVv3cx          54  Catfish and the Bottlemen
# 1    2CgOd0Lj5MuvOqzqdaAXtS          65            Porter Robinson
# 2    4Sfa7hdVkqlM8UW5LsSY3F          69                Passion Pit
# 3    7gMlhlV1AllhpBM8ssg7z6          31   Architecture In Helsinki
# 4    2VcS3oKcOPkubN9LVzZ96l          60  Catfish and the Bottlemen
# ..                      ...         ...                        ...
# 195  5qHirGR7M9tdm6C17DlzSY          75                      Aminé
# 196  4RnvS1tmh1ERhjXX6dxv95          59              Paperboy Fabe
# 197  63bAGRSSX2V1hhPSP2NpBC          67                       ODIE
# 198  0dJhXJKZTpiaxTUc7uItIN          64               Brent Faiyaz
# 199  4X5f3vT8MRuXF68pfjNte5          75                 A$AP Rocky
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.396   0.778    7    -3.990     0       0.0718       0.00246
# 1           0.276   0.796    0    -4.499     1       0.0579       0.00293
# 2           0.566   0.755   11    -5.526     1       0.0368       0.03380
# 3           0.666   0.743    1    -4.478     1       0.0282       0.03660
# 4           0.481   0.765    7    -4.025     1       0.0388       0.00381
# ..            ...     ...  ...       ...   ...          ...           ...
# 195         0.754   0.342   10    -8.677     0       0.0991       0.07300
# 196         0.620   0.721    4    -5.538     0       0.0887       0.04220
# 197         0.802   0.382   10    -7.356     1       0.0312       0.79200
# 198         0.743   0.548    6    -6.545     0       0.0947       0.17500
# 199         0.853   0.693    1    -6.870     1       0.2750       0.02390
#
#      instrumentalness  liveness  valence    tempo  duration_ms
# 0            0.002910    0.0952    0.362  166.846       188440
# 1            0.000000    0.1840    0.260  199.526       218965
# 2            0.000000    0.3150    0.445  101.006       264493
# 3            0.000001    0.1240    0.726  110.971       178147
# 4            0.000737    0.1190    0.465  102.829       232960
# ..                ...       ...      ...      ...          ...
# 195          0.000000    0.1930    0.423  128.981       121347
# 196          0.007500    0.5630    0.770  169.904       150361
# 197          0.163000    0.0783    0.581   99.969       196800
# 198          0.000180    0.0880    0.558   85.017       215058
# 199          0.000000    0.1100    0.662   95.967       233787
#
# [200 rows x 16 columns]

# %%
playlist = group_df.pivot_table(index=['trackName', 'artistName'], aggfunc='size')
playlist

# dups_color_and_shape = df.pivot_table(index=['Color','Shape'], aggfunc='size')
# Out:
# trackName         artistName
# 11:11             TAEYEON                      1
# 21                Gracie Abrams                1
# 2all              Catfish and the Bottlemen    1
# 3 Nights          Dominic Fike                 2
# 7                 Catfish and the Bottlemen    1
#                                               ..
# odds              NIKI                         1
# skeletons         keshi                        1
# talk              keshi                        1
# urs               NIKI                         1
# why are you here  Machine Gun Kelly            1
# Length: 147, dtype: int64

# %%
group_df['trackName'].value_counts()[:n]
# Out:
# Golden                        2
# Daylight                      2
# Tongue Tied                   2
# 3 Nights                      2
# Easily                        1
# all the kids are depressed    1
# I Like U                      1
# 7                             1
# Bluffin                       1
# Lonely (with benny blanco)    1
# Name: trackName, dtype: int64

# %%
maxSongOccurence= group_df['trackName'].value_counts()[0]

# group_df.loc[group_df['trackName'].value_counts() == maxSongOccurence, 'added_to_playlist'] = True  
group_df
# Out:
# c:\users\laibr\appdata\local\programs\python\python38\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\laibr\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     616         try:
# --> 617             return self._convert_to_indexer(key, axis=0, is_setter=True)
#     618         except TypeError as e:
#
# c:\users\laibr\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, key, axis, is_setter)
#    1197                 # When setting, missing keys are not allowed, even with .loc:
# -> 1198                 return self._get_listlike_indexer(key, axis, raise_missing=True)[1]
#    1199         else:
#
# c:\users\laibr\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1248         if ax.is_unique and not getattr(ax, "is_overlapping", False):
# -> 1249             indexer = ax.get_indexer_for(keyarr)
#    1250             keyarr = ax.reindex(keyarr)[0]
#
# c:\users\laibr\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_indexer_for(self, target, **kwargs)
#    4706         if self.is_unique:
# -> 4707             return self.get_indexer(target, **kwargs)
#    4708         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#
# c:\users\laibr\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\range.py in get_indexer(self, target, method, limit, tolerance)
#     373             # checks/conversions/roundings are delegated to general method
# --> 374             return super().get_indexer(target, method=method, tolerance=tolerance)
#     375
#
# c:\users\laibr\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2974             target = target.astype(object)
# -> 2975             return this.get_indexer(
#    2976                 target, method=method, limit=limit, tolerance=tolerance
#
# c:\users\laibr\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2999
# -> 3000             indexer = self._engine.get_indexer(target._get_engine_target())
#    3001
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# c:\users\laibr\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1664     def __hash__(self):
# -> 1665         raise TypeError(
#    1666             f"{repr(type(self).__name__)} objects are mutable, "
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
#
# The above exception was the direct cause of the following exception:
#
# IndexingError                             Traceback (most recent call last)
# <ipython-input-18-a2e9455cb3d4> in <module>
#       1 maxSongOccurence= group_df['trackName'].value_counts()[0]
#       2
# ----> 3 group_df.loc[group_df['trackName'].value_counts() == maxSongOccurence, 'added_to_playlist'] = True
#       4 group_df
#
# c:\users\laibr\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     664         else:
#     665             key = com.apply_if_callable(key, self.obj)
# --> 666         indexer = self._get_setitem_indexer(key)
#     667         self._has_valid_setitem_indexer(key)
#     668
#
# c:\users\laibr\appdata\local\programs\python\python38\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     623             elif "unhashable type" in str(e):
#     624                 raise
# --> 625             raise IndexingError(key) from e
#     626
#     627     def _ensure_listlike_indexer(self, key, axis=None):
#
# IndexingError: (Golden                          True
# Daylight                        True
# Tongue Tied                     True
# 3 Nights                        True
# Easily                         False
#                                ...
# Streetcar                      False
# Shoota (feat. Lil Uzi Vert)    False
# Lions, Tigers & Bears          False
# Selene                         False
# Feeling Whitney                False
# Name: trackName, Length: 196, dtype: bool, 'added_to_playlist')

# %% [markdown]
# ## Compliling data and using it to build the correlation matrix to identify the attributes linked to popularity

# %%
f1 = pd.read_json("data/SpotifyData.json")

df_BL = pd.read_csv("data/brendan-spotify.csv")
df_NL = pd.read_csv("data/nick-spotify.csv")
df_BT = pd.read_csv("data/btam-spotify.csv")
df_DD = pd.read_csv("data/danica-spotify.csv")
df_TLC = pd.read_csv("data/toma-spotify.csv")

frames = [df_BL, df_NL, df_BT, df_DD, df_TLC]

personal_df = pd.concat(frames).reset_index(drop=True) 
f1 = f1.drop(columns=['track_id', 'key', 'mode', 'time_signature', 'duration_ms','instrumentalness'])

# Rename certain columns
personal_df = personal_df.rename(columns={"Song": "track_name", 
                            "Artist": "artist_name", 
                            "dance": "danceability", 
                            "dB": "loudness",
                            "bpm": "tempo",
                            "liveliness":"liveness",
                            })

# Rearrange to match order of master set
personal_df = personal_df[['artist_name', 
                           'track_name',
                           'popularity',
                           'danceability',
                           'energy',
                           'speechiness',
                           'acousticness',
                           'liveness',
                           'valence',
                           'tempo',]]

df = pd.concat([f1, personal_df])
df = df.drop_duplicates(subset=['track_name','artist_name'], keep='first', inplace=False, ignore_index=False )
df = df.drop(["loudness"], axis=1)

# %%
df_personal = pd.concat(frames)
df_personal
# Out:
#                                             Song                Artist  \
# 0                                Sooner Or Later          Aaron Carter
# 1                              This is the Place           Tom Grennan
# 2               Found What I've Been Looking For           Tom Grennan
# 3                   Strive (feat. Missy Elliott)             A$AP Ferg
# 4                                  What You Know  Two Door Cinema Club
# ..                                           ...                   ...
# 245                                       Roller            April Wine
# 246               Ziggy Stardust - 1990 Remaster           David Bowie
# 247                      Two Tickets To Paradise           Eddie Money
# 248                         Bad Side of the Moon            April Wine
# 249  (It Ain't Nothin' But A) House Party - Live     The J. Geils Band
#
#                  Genre  Year       added  bpm  energy  dance  dB  liveliness  \
# 0            dance pop  2018  2021‑01‑06  112      73     74  -7           7
# 1    indie anthem-folk  2020  2021‑01‑05  142      62     65  -5           9
# 2    indie anthem-folk  2018  2021‑01‑05  107      83     62  -5           8
# 3              hip hop  2016  2021‑01‑04  124      82     84  -6           9
# 4    alternative dance  2010  2021‑01‑03  139      74     56  -4           8
# ..                 ...   ...         ...  ...     ...    ...  ..         ...
# 245         album rock  1991  2015‑09‑27  141      90     43  -5          14
# 246         album rock  1990  2017‑03‑21  161      51     41 -14          38
# 247         album rock  1999  2018‑03‑01  130      85     60  -8          10
# 248         album rock  1991  2017‑03‑21  181      78     41 -10          25
# 249         album rock  2012  2015‑09‑27   79      88     25  -5          58
#
#      valence  duration  acousticness  speechiness  popularity
# 0         44       213            12            4          49
# 1         46       186            32            3          68
# 2         78       192             4            3          62
# 3         83       170            34           13          41
# 4         78       192             0            4          70
# ..       ...       ...           ...          ...         ...
# 245       66       217             0            9          35
# 246       51       194             7           12          35
# 247       70       238            20            3          29
# 248       54       193            83           34          26
# 249       51       343             3            6          19
#
# [3695 rows x 15 columns]

# %%
# f1['popularity'].value_counts()[0]
f1.hist(figsize=(25,25))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F345A6DB50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F345E37FD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F345FC9460>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F346BBD8B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F3430B4CA0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F3469D20A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001F3469D2190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F345C33640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001F34642BE50>]],
#       dtype=object)

# %%
df.hist(figsize=(25,25));
