# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_BL = pd.read_csv("data/brendan-spotify.csv")
df_NL = pd.read_csv("data/nick-spotify.csv")
df_BT = pd.read_csv("data/btam-spotify.csv")
df_DD = pd.read_csv("data/danica-spotify.csv")
df_TLC = pd.read_csv("data/toma-spotify.csv")

print("song data read successfully!")
# Out:
# song data read successfully!

# %%
# Clean data
df_BL = df_BL.drop(columns=['added'])
df_NL = df_NL.drop(columns=['added'])
df_BT = df_BT.drop(columns=['added'])
df_DD = df_DD.drop(columns=['added'])
df_TLC = df_TLC.drop(columns=['added'])

# %%
def PrintCombinedPlaylist(frames, playlistLen):
    """
    frames: list of the df containing indvidiual song libraries
    playlistLen: Length of the desired playlist
    """
    if(type(playlistLen) != (int)):
        return "playlist length not type int"
    
    # Concatenate all the 
#   df = pd.concat(frames)
    df = pd.concat(frames).drop_duplicates().reset_index(drop=True)
    
    # Calculate required values
    num_songs = len(df)
    means = df.mean(axis = 0, skipna = True) 
    
    # Calculates song difference attribute for each song
    df = df.assign(delta=lambda x: 
                       abs(x['energy'] - means['energy'])
                       + abs(x['dance'] - means['dance'])
                       + abs(x['liveliness'] - means['liveliness'])
                       + abs(x['valence'] - means['valence'])
#                        + abs(x['acousticness'] - means['acousticness'])
#                        + abs(x['speechiness'] - means['speechiness'])
                  )
    
    return (df.sort_values(by='delta', ascending=True).head(playlistLen)[['Song', 'Artist']])
  
# Attempt at trying to make happy/sad playlists
def MoodBasedPlaylist(frames, playlistLen, moodProfile):
    """
    frames: list of the df containing individual song libraries
    playlistLen: Length of the desired playlist output
    moodProfile: List [energy, dance, liveliness, valence] providing the mood desired
    """
    
    if(type(playlistLen) != (int)):
        return "playlist length not type int"
    
    # Concatenate all the 
#     df = pd.concat(frames)
    df = pd.concat(frames).drop_duplicates().reset_index(drop=True)

    
    # Calculates song difference attribute for each song
    df = df.assign(delta=lambda x: 
                       abs(x['energy'] - moodProfile[0])
                       + abs(x['dance'] - moodProfile[1])
                       + abs(x['liveliness'] - moodProfile[2])
                       + abs(x['valence'] - moodProfile[3]
                       + abs(x['popularity']- moodProfile[4]))
                  )
    
    return (df.sort_values(by='delta', ascending=True).head(playlistLen)[['Song', 'Artist']])

# %%
frames = [df_BL, df_BT, df_DD, df_NL, df_TLC]
df = pd.concat(frames)

# Help provide context on what to use for the mood profile list
df.plot(y=['energy', 'dance','liveliness', 'valence'],kind='density', xlim=[-20,100], title="Library music profiles normalized")

# def normalize(x, x_max, x_min):
#     return (x - x_min) / (x_max - x_min)

# df_normalized = df.copy()
# df_normalized['energy'] = df_normalized['energy'].apply(lambda x: normalize(x, df['energy'].max(), df['energy'].min()))
# df_normalized['dance'] = df_normalized['dance'].apply(lambda x: normalize(x, df['dance'].max(), df['dance'].min()))
# df_normalized['liveliness'] = df_normalized['liveliness'].apply(lambda x: normalize(x, df['liveliness'].max(),df['liveliness'].min()))
# df_normalized['valence'] = df_normalized['valence'].apply(lambda x: normalize(x, df['valence'].max(),df['valence'].min()))
# df_normalized['acousticness'] = df_normalized['acousticness'].apply(lambda x: normalize(x, df['acousticness'].max(), df['acousticness'].min()))
# df_normalized['speechiness'] = df_normalized['speechiness'].apply(lambda x: normalize(x, df['speechiness'].max(), df['speechiness'].min()))

# df_normalized.plot(y=['energy', 'dance','liveliness', 'valence'],kind='density', xlim=[-0.2,1.2], title="Library music profiles")

# %%
# Tinker with the values to try see what gives accurate reps

# Party list
# [Energy, dancability, liveliness, valence, popularity]
partyProfile = [80, 85, 40, 70, 90]
MoodBasedPlaylist([df_BL, df_NL, df_DD, df_BT, df_TLC], 15, partyProfile)
# Out:
#                                     Song             Artist
# 715                      I'm Not Alright        Loud Luxury
# 763   Hips Don't Lie (feat. Wyclef Jean)            Shakira
# 3134                        make believe      lovelytheband
# 75           I Just Don't Care That Much        Matt Maeson
# 1316                                Mine              Bazzi
# 1049                Right Now (Na Na Na)               Akon
# 2168          Chlorine - Alternative Mix  Twenty One Pilots
# 1094  California Love - Original Version               2Pac
# 774                              TiK ToK              Kesha
# 2009                         Grace Kelly               MIKA
# 191                            Over Life           Distrion
# 1906                       Chasing Highs               ALMA
# 108                        Take A Minute             K'NAAN
# 573       You Don't Know Me (feat. RAYE)          Jax Jones
# 1925                          Why Not Me           Forrest.

# %% [markdown]
# ##### PrintCombinedPlaylist([df_TLC, df_BT, df_DD, df_NL], 20)

# %%
# Key Variables
num_songsBL = len(df_BL.index)
meansBL = df_BL.mean(axis = 0, skipna = True) 
mediansBL = df_BL.median(axis = 0, skipna = True)

num_songsNL = len(df_NL.index)
meansNL = df_NL.mean(axis = 0, skipna = True) 
mediansNL = df_NL.median(axis = 0, skipna = True)

num_songsBT = len(df_BT.index)
meansBT = df_BT.mean(axis = 0, skipna = True) 
mediansBT = df_BT.median(axis = 0, skipna = True)

num_songsDD = len(df_DD.index)
meansDD = df_DD.mean(axis = 0, skipna = True) 
mediansDD = df_DD.median(axis = 0, skipna = True)

num_songsTLC = len(df_TLC.index)
meansTLC = df_TLC.mean(axis = 0, skipna = True) 
mediansTLC = df_TLC.median(axis = 0, skipna = True)

# print("Brendan Mean statistics:\n", meansBL)
# print("\n\nNick Mean statistics:\n", meansNL)
# print("\n\nBTam Mean statistics:\n", meansBT)
# print("\n\nDanica Mean statistics:\n", meansDD)

# %%
# Most common songs to show up in the total dataset
frames = [df_BL, df_BT, df_DD, df_NL]
df = pd.concat(frames)
songs = df.groupby(['Song', 'Artist']).size()
songs = songs.to_frame(name='count').reset_index()
songs.sort_values(by='count', ascending=False).head(50)

genre_df = df['Genre'].value_counts()
popular_genres = genre_df.drop(genre_df[genre_df < 20].index)
print("\nAll genres occuring at least 20 times")
print(popular_genres)

# normalized data
# normalized_df=(genre_df-genre_df.mean())/genre_df.std()
normalized_df=(genre_df-genre_df.min())/(genre_df.max()-genre_df.min())
# Out:
# All genres occuring at least 20 times
# dance pop                    496
# indie pop                    199
# electropop                   155
# big room                     152
# contemporary country         137
# alternative r&b              132
# pop                          102
# folk-pop                      97
# modern rock                   93
# bedroom pop                   78
# edm                           73
# canadian pop                  59
# baroque pop                   39
# alternative dance             39
# ambient worship               38
# dfw rap                       37
# modern alternative rock       36
# australian pop                34
# canadian contemporary r&b     34
# atl hip hop                   33
# indie folk                    30
# indie poptimism               30
# neo mellow                    29
# bedroom soul                  29
# boy band                      27
# permanent wave                27
# indie cafe pop                26
# brostep                       26
# irish singer-songwriter       26
# hollywood                     25
# acoustic pop                  25
# australian dance              24
# hip hop                       23
# pop rap                       22
# compositional ambient         20
# Name: Genre, dtype: int64

# %%
# Genre information
genre_df = df['Genre'].value_counts()
popular_genres = genre_df.drop(genre_df[genre_df < 15].index)
print("\nAll genres occuring at least 20 times")
print(popular_genres)

# normalized data
# normalized_df=(genre_df-genre_df.mean())/genre_df.std()
normalized_df=(genre_df-genre_df.min())/(genre_df.max()-genre_df.min())

# normalized_df.head(15)
# Out:
# All genres occuring at least 20 times
# dance pop                    333
# contemporary country         135
# big room                     134
# alternative r&b               65
# pop                           64
# electropop                    63
# indie pop                     62
# edm                           48
# ambient worship               37
# folk-pop                      36
# modern rock                   35
# canadian pop                  34
# baroque pop                   31
# dfw rap                       29
# australian pop                27
# hollywood                     25
# alternative dance             25
# brostep                       24
# atl hip hop                   23
# bedroom pop                   22
# modern alternative rock       20
# compositional ambient         20
# indie cafe pop                18
# canadian contemporary r&b     17
# indie poptimism               16
# irish singer-songwriter       16
# circus                        16
# hip hop                       15
# melodic rap                   15
# Name: Genre, dtype: int64

# %%
# Spotify defined "Happiest" songs
df.sort_values(by='valence', ascending=False).head(25)
# Out:
#                                          Song                  Artist  \
# 19                            Pumped Up Kicks       Foster The People
# 46            There's Nothing Holdin' Me Back            Shawn Mendes
# 442                              Wake Up Call                Maroon 5
# 1148  Alfie's Song (Not So Typical Love Song)               Bleachers
# 415                                   Hey Ya!                 Outkast
# 180             Troublemaker (feat. Flo Rida)               Olly Murs
# 324                           That I Miss You                 Vansire
# 8                                     Hey Ya!                 Outkast
# 36                            Pumped Up Kicks       Foster The People
# 1026                                Chit Chat           Beach Weather
# 833                              Shine On Top                Surfaces
# 54                            Pumped Up Kicks       Foster The People
# 874                              Oxford Comma         Vampire Weekend
# 474                                   Goodbye             Jagged Edge
# 827                                     Cynic              Noah Kahan
# 1357               Bound to Be Something Good            The Colonies
# 470                Bailando - English Version        Enrique Iglesias
# 443       Second Emotion (feat. Travis Scott)           Justin Bieber
# 338               P.Y.T. (Pretty Young Thing)         Michael Jackson
# 333                                 Hotel Key            Old Dominion
# 1168                                  Cassidy            Brett Dennen
# 188                     Red Light Green Light             Duke Dumont
# 1245                     Running Through Hell  The Head and the Heart
# 217                             The Lazy Song              Bruno Mars
# 271              Raindrops - Prince Fox Remix                   SNBRN
#
#                      Genre  Year  bpm  energy  dance  dB  liveliness  valence  \
# 19               indie pop  2011  128      71     73  -6          10       97
# 46            canadian pop  2017  122      81     87  -4           8       97
# 442                    pop  2007  164      95     63  -3           9       97
# 1148       double drumming  2018  142      88     63  -6          35       97
# 415            atl hip hop  2006   80      95     71  -5          19       97
# 180              dance pop  2012  106      86     76  -4          13       97
# 324            bedroom pop  2018  115      57     78  -9          11       97
# 8              atl hip hop  2006   80      95     71  -5          19       97
# 36               indie pop  2011  128      71     73  -6          10       97
# 1026                   NaN  2016  142      98     51  -3          33       97
# 833           bedroom soul  2019   83      75     81  -5          14       97
# 54               indie pop  2011  128      71     73  -6          10       97
# 874            baroque pop  2008  120      72     69  -4           4       97
# 474            atl hip hop  2001  130      73     82  -6           5       97
# 827             electropop  2019  103      69     78  -6          33       96
# 1357              dc indie  2019  130      87     75  -8           6       96
# 470              dance pop  2014   91      85     72  -4           7       96
# 443           canadian pop  2020  142      78     80  -6          10       96
# 338                    pop  1982  127      82     89  -5          13       96
# 333   contemporary country  2017  102      87     76  -5          31       96
# 1168          acoustic pop  2016   84      60     60 -10           8       96
# 188              dance pop  2019  124      83     81  -5           7       95
# 1245              folk-pop  2019  123      72     76  -7          12       95
# 217              dance pop  2010  175      80     74  -4          28       95
# 271             bass house  2015  140      94     75  -3          17       95
#
#       duration  acousticness  speechiness  popularity
# 19         240            14            3          86
# 46         199            38            6          84
# 442        201             3            6          55
# 1148       181             4            8          47
# 415        236             7            6          60
# 180        186             2            6          75
# 324        140            31            4          64
# 8          236             7            6          60
# 36         240            14            3          86
# 1026       200             0            6          53
# 833        145            14           17          60
# 54         240            14            3          86
# 874        196            11            5          58
# 474        273            13           11          46
# 827        208            23            3          60
# 1357       246            24            5          20
# 470        243             8           10          47
# 443        203             3            6          68
# 338        239            23            4          73
# 333        167            15            5          68
# 1168       268            18            3          46
# 188        211             0            7          71
# 1245       220             1            3          40
# 217        190            33            6          73
# 271        242            14            9          34

# %%
# Spotify defined "energetic"

df.sort_values(by='energy', ascending=False).head(25)
# Out:
#                                                    Song  \
# 1305                  That Don't Impress Me Much - Live
# 1311  (If You're Not In It For Love) I'm Outta Here!...
# 322                                    Somebody Told Me
# 671                             Cinema - Skrillex Remix
# 1026                                          Chit Chat
# 593                         If These Sheets Were States
# 444                                  Everytime We Touch
# 859                           Right Round (feat. Ke$ha)
# 416                                             Crusade
# 96                                          Jerk It Out
# 197                                         Promiscuous
# 364                                          Love Drunk
# 665   Saturday Night’s Alright (For Fighting) - Rema...
# 403                                   Backseat Serenade
# 529                                    Out of My League
# 641                                  Cinderblock Garden
# 204                      Bad (feat. Vassy) - Radio Edit
# 265                                    Out of My League
# 172                                        BURN IT DOWN
# 329                               Call It What You Want
# 1277                             Any Man Of Mine - Live
# 520                           Old Scars / Future Hearts
# 395                                        The Overpass
# 1332                          I Ain't No Quitter - Live
# 406                 Jet Lag (feat. Natasha Bedingfield)
#
#                      Artist               Genre  Year  bpm  energy  dance  dB  \
# 1305           Shania Twain    canadian country  2015  125     100     67  -4
# 1311           Shania Twain    canadian country  2015  120      99     58  -2
# 322             The Killers         modern rock  2004  138      99     51  -3
# 671           Benny Benassi         disco house  2011  145      99     64  -4
# 1026          Beach Weather                 NaN  2016  142      98     51  -3
# 593            All Time Low         modern rock  2012  175      98     42  -4
# 444                 Cascada     bubblegum dance  2006  142      98     63  -5
# 859                Flo Rida           dance pop  2009  129      98     45  -3
# 416              Marshmello             brostep  2020  140      98     62  -1
# 96                  Caesars  swedish indie rock  2005  134      98     58  -3
# 197           Nelly Furtado      canadian latin  2006  114      98     80  -6
# 364         Boys Like Girls           dance pop  2009  150      98     44  -3
# 665              Elton John           glam rock  1973  153      98     51  -6
# 403            All Time Low         modern rock  2012  140      97     51  -4
# 529   Fitz and The Tantrums           indie pop  2013  170      97     55  -4
# 641            All Time Low         modern rock  2015  158      97     49  -4
# 204            David Guetta           dance pop  2014  128      97     61  -4
# 265   Fitz and The Tantrums           indie pop  2013  170      97     55  -4
# 172             Linkin Park   alternative metal  2012  110      97     59  -4
# 329       Foster The People           indie pop  2011  113      97     64  -4
# 1277           Shania Twain    canadian country  2015   80      97     50  -3
# 520            All Time Low         modern rock  2015  175      97     39  -4
# 395     Panic! At The Disco         baroque pop  2018  133      96     52  -2
# 1332           Shania Twain    canadian country  2015  161      96     49  -3
# 406             Simple Plan   canadian pop punk  2011  145      96     54  -3
#
#       liveliness  valence  duration  acousticness  speechiness  popularity
# 1305          56       80       232             0            4          32
# 1311          98       75       298             0            6          31
# 322           12       65       197             0            9          68
# 671            6       37       308             1           18          64
# 1026          33       97       200             0            6          53
# 593           31       57       199             0            7          49
# 444           45       45       196             0            5          55
# 859           22       16       203             5           29          58
# 416           33       49       171             3            8          61
# 96            39       86       196             2            6          66
# 197           14       84       242             5            5          74
# 364           16       41       227             0           14          66
# 665            9       94       295             2            4          48
# 403           17       49       201             0            5          60
# 529           33       53       209             4            9          68
# 641           20       59       216             1           11          46
# 204           33       41       171             0            9          66
# 265           33       53       209             4            9          75
# 172            7       59       230             1            5          75
# 329           44       73       239             5            6          64
# 1277          81       69       270             1            6          37
# 520            5       50       207             0           17          54
# 395           36       61       178             2           17          60
# 1332          99       82       250             6           10          27
# 406           16       69       205             0            6          62

# %%
# Spotify defined "saddest" songs

df.sort_values(by='valence', ascending=True).head(25)
# Out:
#                                     Song              Artist  \
# 822                       Airplane Cabin    Sleep Baby Sleep
# 547  Une barque sur l'océan from Miroirs      André Laplante
# 791                            Aftermath    Cirque du Soleil
# 313                         All The Time             Jeremih
# 375                                Light    Sleeping At Last
# 733                         Lili's Dream   Alexandre Desplat
# 743                           Aggression   Alexandre Desplat
# 744                         Lili's Death   Alexandre Desplat
# 750                           The Mirror   Alexandre Desplat
# 669                     Days in The East               Drake
# 757                        Watching Ulla   Alexandre Desplat
# 759                               Saturn    Sleeping At Last
# 330                        In This Shirt  The Irrepressibles
# 763                           To Dresden   Alexandre Desplat
# 764                            O Makunde    Cirque du Soleil
# 768                    Gerda In The Rain   Alexandre Desplat
# 771                             Watching   Alexandre Desplat
# 776                   Einar Returns Home   Alexandre Desplat
# 777                            Radiation   Alexandre Desplat
# 780                           Fonnesbech   Alexandre Desplat
# 781                           Lost Blood   Alexandre Desplat
# 782                               Uranus    Sleeping At Last
# 783                           Shadowplay    Cirque du Soleil
# 784                               Flight    Cirque du Soleil
# 815                                 Rain       Evgeny Khmara
#
#                         Genre  Year  bpm  energy  dance  dB  liveliness  \
# 822                     sleep  2016  127      23     17 -39          16
# 547  canadian classical piano  2017   68      11     29 -22           9
# 791                    circus  2005   80      28      8 -13          15
# 313               chicago rap  2013  110      44     68  -9          20
# 375           ambient worship  2014  105      39     22  -9           7
# 733     compositional ambient  2015   74       7     12 -23          11
# 743     compositional ambient  2015  128       9     21 -19          10
# 744     compositional ambient  2015  104       5     20 -21           9
# 750     compositional ambient  2015   76      11      7 -16          26
# 669          canadian hip hop  2019   95      36     73 -11           9
# 757     compositional ambient  2015   56       5     24 -34          10
# 759           ambient worship  2013  145      23     17 -14          10
# 330               baroque pop  2009   80      48     31  -6          13
# 763     compositional ambient  2015   75      15     11 -18           8
# 764                    circus  2005  110      26     46 -13          33
# 768     compositional ambient  2015   81       1     15 -27          12
# 771     compositional ambient  2015   66       7     13 -22          30
# 776     compositional ambient  2015  144      12     43 -22          10
# 777     compositional ambient  2015   81       3      8 -24          11
# 780     compositional ambient  2015  144      17     34 -20           9
# 781     compositional ambient  2015  164       3     38 -30          11
# 782           ambient worship  2013  135      22     19 -18           6
# 783                    circus  2005  113      23     17 -14          14
# 784                    circus  2005  135      29     21  -9          12
# 815                       NaN  2017  140      25     25 -15          12
#
#      valence  duration  acousticness  speechiness  popularity
# 822        2       300            99            6           3
# 547        3       431            98            4          52
# 791        3       138            79            4          21
# 313        3       264            55           35          73
# 375        4       263            53            3          61
# 733        4       324            94            3          36
# 743        4       216            94            4          34
# 744        4       284            97            4          34
# 750        4       237            51            4          32
# 669        4       354            35           14          57
# 757        4       127            97            4          29
# 759        4       289            64            4          29
# 330        4       335            71            3          73
# 763        4       142            95            4          28
# 764        4       187            78            3          28
# 768        4       242            97            4          27
# 771        4       208            48            4          26
# 776        4        98            84            4          25
# 777        4       142            95            4          25
# 780        4       104            97            3          24
# 781        4       136            92            3          24
# 782        4       260            87            4          24
# 783        4       227            91            4          24
# 784        4       145            83            3          24
# 815        4       211            94            4           8
