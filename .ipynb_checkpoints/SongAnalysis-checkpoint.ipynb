# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df_BL = pd.read_csv("data/brendan-spotify.csv")
df_NL = pd.read_csv("data/nick-spotify.csv")
df_BT = pd.read_csv("data/btam-spotify.csv")
df_DD = pd.read_csv("data/danica-spotify.csv")
df_TLC = pd.read_csv("data/toma-spotify.csv")

print("song data read successfully!")
# Out:
# song data read successfully!

# %%
# Clean data
df_BL = df_BL.drop(columns=['added'])
df_NL = df_NL.drop(columns=['added'])
df_BT = df_BT.drop(columns=['added'])
df_DD = df_DD.drop(columns=['added'])
df_TLC = df_TLC.drop(columns=['added'])

# %% [markdown]
# ## Trying to create group profile centred playlists using the following methods

# %%
def PrintCombinedMeanPlaylist(frames, playlistLen):
    """
    frames: list of the df containing indvidiual song libraries
    playlistLen: Length of the desired playlist
    """
    if(type(playlistLen) != (int)):
        return "playlist length not type int"
    
    # Concatenate all the datasets drop any duplicates
    df = pd.concat(frames).drop_duplicates().reset_index(drop=True)
    
    # Calculate required values
    num_songs = len(df)
    means = df.mean(axis = 0, skipna = True) 
    
    # Calculates song difference attribute for each song
    df = df.assign(delta=lambda x: 
                       abs(x['energy'] - means['energy']) * 0.25
                       + abs(x['dance'] - means['dance']) * 0.25
                       + abs(x['liveliness'] - means['liveliness']) * 0.25
                       + abs(x['valence'] - means['valence']) * 0.25
                  )
    
    return (df.sort_values(by='delta', ascending=True).head(playlistLen)[['Song', 'Artist']])
      
def PrintCombinedMedianPlaylist(frames, playlistLen):
    """
    frames: list of the df containing indvidiual song libraries
    playlistLen: Length of the desired playlist
    """
    if(type(playlistLen) != (int)):
        return "playlist length not type int"
    
    # Concatenate all the datasets drop any duplicates
    df = pd.concat(frames).drop_duplicates().reset_index(drop=True)
    
    # Calculate required values
    num_songs = len(df)
    medians = df.median(axis = 0, skipna = True) 
    
    # Calculates song difference attribute for each song
    df = df.assign(delta=lambda x: 
                       abs(x['energy'] - medians['energy']) * 0.25
                       + abs(x['dance'] - medians['dance']) * 0.25
                       + abs(x['liveliness'] - medians['liveliness']) * 0.25
                       + abs(x['valence'] - medians['valence']) * 0.25
                  )
    
    return (df.sort_values(by='delta', ascending=True).head(playlistLen)[['Song', 'Artist']])

# %% [markdown]
# ## Way to try make mood based group playlists

# %%
def MoodBasedPlaylist(frames, playlistLen, moodProfile, weightParams):
    """
    frames: list of the df containing individual song libraries
    playlistLen: Length of the desired playlist output
    moodProfile: List [energy, dance, liveliness, valence, popularity] providing the mood desired
    """
    if(type(playlistLen) != (int)):
        return "playlist length not type int"
    
    # Concatenate all the 
    df = pd.concat(frames).drop_duplicates().reset_index(drop=True)
    
    # Calculates song difference attribute for each song
    df = df.assign(delta=lambda x: 
                       abs(x['energy'] - moodProfile[0]) * weightParams[0]
                       + abs(x['dance'] - moodProfile[1]) * weightParams[1]
                       + abs(x['valence'] - moodProfile[2]) * weightParams[2]
                       + abs(x['popularity']- moodProfile[3]) * weightParams[3]
                  )
    
    return (df.sort_values(by='delta', ascending=True).head(playlistLen)[['Song', 'Artist']])

# %%
frames = [df_BL, df_BT, df_DD, df_NL, df_TLC]
df = pd.concat(frames).drop_duplicates().reset_index(drop=True)

# Help provide context on what to use for the mood profile list
df.plot(y=['energy', 'dance','liveliness', 'valence'],kind='density', xlim=[-20,100], title="Library music profiles")

group_means = df.mean(axis = 0, skipna = True) 
# print(group_means)

group_medians = df.median(axis = 0, skipna = True)
# print(group_medians)

print("Some basic information that can help you derive useful parameters for the algorithms")

genre_df = df['Genre'].value_counts()
popular_genres = genre_df.drop(genre_df[genre_df < 40].index)
print("\nAll genres occuring at least 40 times")
print(popular_genres)
# Out:
# Some basic information that can help you derive useful parameters for the algorithms
#
# All genres occuring at least 40 times
# dance pop               473
# indie pop               175
# big room                149
# album rock              142
# electropop              140
# contemporary country    135
# alternative r&b         116
# pop                      98
# modern rock              96
# folk-pop                 87
# bedroom pop              71
# edm                      70
# canadian pop             50
# Name: Genre, dtype: int64

# %% [markdown]
# # Tinker with the party profile list to try optimize a playlist based solution.
# [ Energy , Dancability, Liveliness, Valence, Popularity ]
#
# ### TBD trying to determine the best weightings above as well for inside the delta function

# %%
# Party list
weightParams = [0.2, 0.3, 0, 0.25, 0.25]
partyProfile = [90, 85, 70, 80, 85] 
print("Party playlist??\n", MoodBasedPlaylist([df_BL, df_NL, df_DD, df_BT, df_TLC], 15, partyProfile, weightParams))

# Sad list
weightParams = [0.225, 0.225, 0, 0.15, 0.25]
sadProfile = [30, 20, 10, 15, 75]
print("\n\nSad playlist??\n", MoodBasedPlaylist([df_BL, df_NL, df_DD, df_BT, df_TLC], 15, sadProfile, weightParams))
# Out:
# Party playlist??
#                                              Song                    Artist
# 244                                      Secrets                    Regard
# 763           Hips Don't Lie (feat. Wyclef Jean)                   Shakira
# 930                                   Poker Face                 Lady Gaga
# 759                             Hey, Soul Sister                     Train
# 428                                  This Groove            Oliver Heldens
# 815                                   Not Afraid                    Eminem
# 3253   Should I Stay or Should I Go - Remastered                 The Clash
# 794                                    This Love                  Maroon 5
# 522        Prayer in C - Robin Schulz Radio Edit  Lilly Wood and The Prick
# 1811                                   Your Soul                  Forrest.
# 774                                      TiK ToK                     Kesha
# 219   Ooh Ahh (My Life Be Like) (feat. Toby Mac)                     Grits
# 822                                      Whistle                  Flo Rida
# 927                                  Promiscuous             Nelly Furtado
# 1258             There's Nothing Holdin' Me Back              Shawn Mendes
#
#
# Sad playlist??
#                                           Song             Artist
# 2657                        Visions of Gideon     Sufjan Stevens
# 2575                         A Million Dreams        Ziv Zaifman
# 2658                                  Flicker        Niall Horan
# 3319               Bridge Over Troubled Water  Simon & Garfunkel
# 2660                                   Saturn   Sleeping At Last
# 1143  Untitled (How Could This Happen to Me?)        Simple Plan
# 2538                               All I Want           Kodaline
# 2622                                Streetcar      Daniel Caesar
# 2569                             Turning Page   Sleeping At Last
# 2639                                Tightrope  Michelle Williams
# 1260                                  Fix You           Coldplay
# 480                                 Streetcar      Daniel Caesar
# 2576                             Never Enough       Loren Allred
# 1353                             Never Enough       Loren Allred
# 3368                             Brain Damage         Pink Floyd

# %%
print("Mean centred group profile:\n", PrintCombinedMeanPlaylist([df_BL, df_NL, df_TLC], 15))
print("\n\nMedian centered group profile:\n", PrintCombinedMedianPlaylist([df_BL, df_NL, df_TLC], 15))
# Out:
# Mean centred group profile:
#                                 Song                 Artist
# 735                     You Make Me                 Avicii
# 536   Favorite Sound - BRKLYN Remix                 Audien
# 1048                 Take Your Time               Sam Hunt
# 938                     Eyes On You             Chase Rice
# 935              Every Other Memory              Ryan Hurd
# 393              Somebody Loves You            White Panda
# 345     Losing You (feat. Mougleta)                offrami
# 1254                    Scar Tissue  Red Hot Chili Peppers
# 863                         Bad Day          Daniel Powter
# 487          Mean It (feat. Wrabel)              Cash Cash
# 489     Not Coming Home (feat. JRM)                 Matoma
# 570                    Push My Luck       The Chainsmokers
# 999                  Better in Time            Leona Lewis
# 714        Gold Roses (feat. Drake)              Rick Ross
# 55                    Cold Cold Man            Saint Motel
#
#
# Median centered group profile:
#                                                     Song                 Artist
# 735                                         You Make Me                 Avicii
# 935                                  Every Other Memory              Ryan Hurd
# 345                         Losing You (feat. Mougleta)                offrami
# 393                                  Somebody Loves You            White Panda
# 863                                             Bad Day          Daniel Powter
# 1254                                        Scar Tissue  Red Hot Chili Peppers
# 503   Stay The Night - Featuring Hayley Williams Of ...                   Zedd
# 999                                      Better in Time            Leona Lewis
# 55                                        Cold Cold Man            Saint Motel
# 695                                          The Motion                  Drake
# 589                                         Fedrelandet          Gaute Ormåsen
# 564                                       Rollercoaster                 Audien
# 466                                              Fading                Shallou
# 1005                                      All To Myself             Dan + Shay
# 1038                                          Breakeven             The Script

# %%
# Spotify defined "Happiest" songs
df.sort_values(by='valence', ascending=False).head(15)
# Out:
#                                           Song              Artist  \
# 2943             Troublemaker (feat. Flo Rida)           Olly Murs
# 8                                      Hey Ya!             Outkast
# 3212                                   Goodbye         Jagged Edge
# 1586           There's Nothing Holdin' Me Back        Shawn Mendes
# 2573   Alfie's Song (Not So Typical Love Song)           Bleachers
# 3267                  Start Me Up - Remastered  The Rolling Stones
# 2456                                 Chit Chat       Beach Weather
# 54                             Pumped Up Kicks   Foster The People
# 1053                           That I Miss You             Vansire
# 2280                              Shine On Top            Surfaces
# 2318                              Oxford Comma     Vampire Weekend
# 3182                              Wake Up Call            Maroon 5
# 3416                          Honky Tonk Women  The Rolling Stones
# 3385  Train in Vain (Stand by Me) - Remastered           The Clash
# 3346                 Smooth (feat. Rob Thomas)             Santana
#
#                 Genre  Year  bpm  energy  dance  dB  liveliness  valence  \
# 2943        dance pop  2012  106      86     76  -4          13       97
# 8         atl hip hop  2006   80      95     71  -5          19       97
# 3212      atl hip hop  2001  130      73     82  -6           5       97
# 1586     canadian pop  2017  122      81     87  -4           8       97
# 2573  double drumming  2018  142      88     63  -6          35       97
# 3267       album rock  1981  122      93     63  -4           9       97
# 2456              NaN  2016  142      98     51  -3          33       97
# 54          indie pop  2011  128      71     73  -6          10       97
# 1053      bedroom pop  2018  115      57     78  -9          11       97
# 2280     bedroom soul  2019   83      75     81  -5          14       97
# 2318      baroque pop  2008  120      72     69  -4           4       97
# 3182              pop  2007  164      95     63  -3           9       97
# 3416       album rock  2019  119      72     56  -7           5       97
# 3385     classic rock  1979  123      72     76  -9          13       97
# 3346       blues rock  1999  116      92     61  -4          30       96
#
#       duration  acousticness  speechiness  popularity
# 2943       186             2            6          75
# 8          236             7            6          60
# 3212       273            13           11          46
# 1586       199            38            6          84
# 2573       181             4            8          47
# 3267       213             4            4          79
# 2456       200             0            6          53
# 54         240            14            3          86
# 1053       140            31            4          64
# 2280       145            14           17          60
# 2318       196            11            5          58
# 3182       201             3            6          55
# 3416       183            23            6          60
# 3385       195             9            4          66
# 3346       295            16            3          71

# %%
# Spotify defined "energetic"

df.sort_values(by='energy', ascending=False).head(15)
# Out:
#                                                    Song           Artist  \
# 2728                  That Don't Impress Me Much - Live     Shania Twain
# 2734  (If You're Not In It For Love) I'm Outta Here!...     Shania Twain
# 670                             Cinema - Skrillex Remix    Benny Benassi
# 3074                                   Somebody Told Me      The Killers
# 2456                                          Chit Chat    Beach Weather
# 3111                                         Love Drunk  Boys Like Girls
# 3184                                 Everytime We Touch          Cascada
# 415                                             Crusade       Marshmello
# 2958                                        Promiscuous    Nelly Furtado
# 2303                          Right Round (feat. Ke$ha)         Flo Rida
# 96                                          Jerk It Out          Caesars
# 664   Saturday Night’s Alright (For Fighting) - Rema...       Elton John
# 1322                        If These Sheets Were States     All Time Low
# 3405                   She Bangs the Drums - Remastered  The Stone Roses
# 2701                             Any Man Of Mine - Live     Shania Twain
#
#                    Genre  Year  bpm  energy  dance  dB  liveliness  valence  \
# 2728    canadian country  2015  125     100     67  -4          56       80
# 2734    canadian country  2015  120      99     58  -2          98       75
# 670          disco house  2011  145      99     64  -4           6       37
# 3074         modern rock  2004  138      99     51  -3          12       65
# 2456                 NaN  2016  142      98     51  -3          33       97
# 3111           dance pop  2009  150      98     44  -3          16       41
# 3184     bubblegum dance  2006  142      98     63  -5          45       45
# 415              brostep  2020  140      98     62  -1          33       49
# 2958      canadian latin  2006  114      98     80  -6          14       84
# 2303           dance pop  2009  129      98     45  -3          22       16
# 96    swedish indie rock  2005  134      98     58  -3          39       86
# 664            glam rock  1973  153      98     51  -6           9       94
# 1322         modern rock  2012  175      98     42  -4          31       57
# 3405    alternative rock  1989  145      98     34  -5          12       67
# 2701    canadian country  2015   80      97     50  -3          81       69
#
#       duration  acousticness  speechiness  popularity
# 2728       232             0            4          32
# 2734       298             0            6          31
# 670        308             1           18          64
# 3074       197             0            9          68
# 2456       200             0            6          53
# 3111       227             0           14          66
# 3184       196             0            5          55
# 415        171             3            8          61
# 2958       242             5            5          74
# 2303       203             5           29          58
# 96         196             2            6          66
# 664        295             2            4          48
# 1322       199             0            7          49
# 3405       232             1            9          62
# 2701       270             1            6          37

# %%
# Spotify defined "saddest" songs

df.sort_values(by='acousticness', ascending=True).head(25)
# Out:
#                                         Song                     Artist  \
# 1713                                Drive By                      Train
# 355                 Say My Name (feat. Zyra)                     ODESZA
# 3256                               Otherside      Red Hot Chili Peppers
# 3260                     More Than a Feeling                     Boston
# 2700                     Let The Record Play                  Moon Taxi
# 348   If You’re Too Shy (Let Me Know) - Edit                   The 1975
# 2699                         Hard to Believe                      HUNNY
# 2690                                Hallways                      HUNNY
# 2680                                   Siren                  Wilderado
# 2674                                One Life                     Hedley
# 1025                      Make Me Your Queen             Declan McKenna
# 3273                 (Don't Fear) The Reaper           Blue Öyster Cult
# 1039                            Disenchanted        My Chemical Romance
# 2653                                Berkeley             Plastic Picnic
# 3274               La Grange - 2005 Remaster                     ZZ Top
# 2652                                Patience                   Bad Suns
# 2640                           Living Mirage     The Head and the Heart
# 2635              You Don't Have To Be Alone       Friends At The Falls
# 2634                             Parking Lot                      HUNNY
# 325                          Sibling Rivalry                        PUP
# 1063                                  Closer                   Lemaitre
# 321                                   Cocoon  Catfish and the Bottlemen
# 3281                               Even Flow                  Pearl Jam
# 3282                           Sweet Emotion                  Aerosmith
# 3255                                Everlong               Foo Fighters
#
#                         Genre  Year  bpm  energy  dance  dB  liveliness  \
# 1713                dance pop  2012  122      84     77  -3           8
# 355                 chillwave  2014  115      75     75  -7           7
# 3256         alternative rock  1999  123      80     46  -3           8
# 3260               album rock  1976  109      68     38  -8           5
# 2700                indie pop  2018  166      86     67  -4          17
# 348   modern alternative rock  2020  126      81     65  -5           9
# 2699                indie pop  2017  147      81     58  -6          38
# 2690                indie pop  2017  155      89     55  -7          16
# 2680       deep new americana  2018  140      68     47  -5          11
# 2674             canadian pop  2011  162      89     59  -4          24
# 1025                indie pop  2017  125      67     49  -6          10
# 3273               album rock  1976  141      93     33  -9          30
# 1039                      emo  2006  174      69     34  -4          11
# 2653               indie rock  2017  112      79     56  -6          18
# 3274               album rock  1973   81      64     55 -10          20
# 2652                indie pop  2016  178      96     52  -5           9
# 2640                 folk-pop  2019   88      67     32  -6          11
# 2635                 hopebeat  2019  124      81     59  -6          14
# 2634                indie pop  2015  104      84     50  -5          36
# 325           alternative emo  2019  105      95     53  -3          13
# 1063        alternative dance  2017   92      79     58  -4          12
# 321   modern alternative rock  2014  133      91     45  -4           8
# 3281         alternative rock  1991  105      94     39  -7          30
# 3282               album rock  1975   99      76     38 -11          10
# 3255        alternative metal  1997  158      88     41  -6           8
#
#       valence  duration  acousticness  speechiness  popularity
# 1713       72       196             0            3          77
# 355        35       263             0            5          67
# 3256       51       255             0            6          80
# 3260       29       285             0            3          80
# 2700       78       189             0            8          37
# 348        39       240             0            3          68
# 2699       61       189             0            4          37
# 2690       87       192             0            4          38
# 2680       28       239             0            4          39
# 2674       66       213             0            7          39
# 1025       26       221             0            3          65
# 3273       39       308             0            7          78
# 1039       15       295             0            4          65
# 2653       61       249             0            3          42
# 3274       61       230             0           22          78
# 2652       54       212             0           16          42
# 2640       24       314             0            3          43
# 2635       39       228             0            4          43
# 2634       47       206             0            5          43
# 325        43       208             0            6          35
# 1063       36       271             0            3          64
# 321        33       237             0            7          66
# 3281       27       293             0            8          77
# 3282       49       274             0            4          77
# 3255       36       251             0            4          80
