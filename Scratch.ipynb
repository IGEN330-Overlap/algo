# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('data/SpotifyData.json')
df.head()
# Out:
#      artist_name              track_name                track_id  popularity  \
# 0       24kGoldn  Mood (feat. iann dior)  3tjFYV6RSFtuktYl3ZtYcq          99
# 1  Ariana Grande                   34+35  6Im9k8u9iIzKMrmV7BWtlF          97
# 2  Ariana Grande               positions  35mvY5S1H3J2QZyna3TFe0          99
# 3             CJ                 Whoopty  5vGLcdRuSbUhD8ScwsGSdA          96
# 4  The Kid LAROI             WITHOUT YOU  27OeeYzk6klgBh83TSvGMA          96
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.700   0.722    7    -3.558     0       0.0369         0.221
# 1         0.830   0.585    0    -6.476     1       0.0940         0.237
# 2         0.737   0.802    0    -4.771     1       0.0878         0.468
# 3         0.711   0.598    3    -7.621     0       0.1820         0.190
# 4         0.662   0.413    0    -7.357     1       0.0299         0.213
#
# ...

# %%
df = df[df.popularity != 0]
# df.info()
# Verify data looks okay
df.hist(figsize=(25,25))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000191BA066970>,
# ...
#       dtype=object)

# %%
df.to_json('tracks.json')
